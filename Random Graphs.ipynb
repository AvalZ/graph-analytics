# %% [markdown]
# # Random Graphs

# %% [markdown]
# Random Graphs (also called Erdős–Rényi models)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.gnp_random_graph(100, 0.01)

nx.draw_random(G, with_labels=True)

plt.show()
